# %%
import pandas as pd
from pandas import DataFrame

# %%
df = pandas.read_csv("/Users/guldenizozdemir/Downloads/yni.csv",sep=';')

# %%
df.head()
# Out:
#   Gün HavaDurumu Sıcaklık      Nem    Yağış  Oyun
# 0  G1    Güneşli    Sıcak   Yüksek   Seyrek   Yok
# 1  G2    Güneşli    Sıcak   Yüksek    Aşırı   Yok
# 2  G3     Kapalı    Sıcak   Yüksek   Seyrek   Var
# 3  G4   Yağmurlu   Ilıman   Yüksek   Seyrek   Var
# 4  G5   Yağmurlu    Soğuk   Normal   Seyrek   Var

# %%
# pandas drop a column with drop function
df.drop(columns=['Sıcaklık', ' Nem'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Gün HavaDurumu    Yağış  Oyun
# 0  G1    Güneşli   Seyrek   Yok
# 1  G2    Güneşli    Aşırı   Yok
# 2  G3     Kapalı   Seyrek   Var
# 3  G4   Yağmurlu   Seyrek   Var
# 4  G5   Yağmurlu   Seyrek   Var

# %%
data = {'Gün': ['G1',
'G2',
'G3',
'G4',
'G5',
'G6',
'G7',
'G8',
'G9',
'G10',
'G11',
'G12',
'G13',
'G14'],
        'HavaDurumu': [ 'Güneşli',
 'Güneşli',
 'Kapalı',
 'Yağmurlu',
 'Yağmurlu',
'Yağmurlu',
'Kapalı',
 'Güneşli',
 'Güneşli',
 'Yağmurlu',
 'Güneşli',
 'Kapalı',
 'Kapalı',
 'Yağmurlu'],
        'Sıcaklık': [ 'Sıcak',
'Sıcak',
'Sıcak',
 'Ilıman',
 'Soğuk',
 'Soğuk',
 'Soğuk',
 'Ilıman',
 'Soğuk',
 'Ilıman',
 'Ilıman',
 'Ilıman',
 'Sıcak',
 'Ilıman'],
        'Nem':['Yüksek',
'Yüksek',
'Yüksek',
'Yüksek',
 'Normal',
 'Normal',
 'Normal',
'Yüksek',
 'Normal',
 'Normal',
 'Normal',
'Yüksek',
 'Normal',
'Yüksek'],
        'Yağış':[ 'Seyrek',
 'Aşırı',
 'Seyrek',
 'Seyrek',
 'Seyrek',
 'Aşırı',
 'Aşırı',
 'Seyrek',
 'Seyrek',
 'Seyrek',
 'Aşırı',
 'Aşırı',
 'Seyrek',
 'Aşırı'],
        'Oyun':[ 'Yok',
 'Yok',
 'Var',
 'Var',
 'Var',
 'Yok',
 'Var',
 'Var',
 'Yok',
 'Var',
 'Var',
 'Yok',
 'Var',
 'Yok'],
       }
                       
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Gün HavaDurumu Sıcaklık     Nem   Yağış Oyun
# 0    G1    Güneşli    Sıcak  Yüksek  Seyrek  Yok
# 1    G2    Güneşli    Sıcak  Yüksek   Aşırı  Yok
# 2    G3     Kapalı    Sıcak  Yüksek  Seyrek  Var
# 3    G4   Yağmurlu   Ilıman  Yüksek  Seyrek  Var
# 4    G5   Yağmurlu    Soğuk  Normal  Seyrek  Var
# 5    G6   Yağmurlu    Soğuk  Normal   Aşırı  Yok
# 6    G7     Kapalı    Soğuk  Normal   Aşırı  Var
# 7    G8    Güneşli   Ilıman  Yüksek  Seyrek  Var
# 8    G9    Güneşli    Soğuk  Normal  Seyrek  Yok
# 9   G10   Yağmurlu   Ilıman  Normal  Seyrek  Var
# 10  G11    Güneşli   Ilıman  Normal   Aşırı  Var
# 11  G12     Kapalı   Ilıman  Yüksek   Aşırı  Yok
# 12  G13     Kapalı    Sıcak  Normal  Seyrek  Var
# 13  G14   Yağmurlu   Ilıman  Yüksek   Aşırı  Yok

# %%
"""
sıcaklık arttıkça, insanların oyun oynamaya daha yatkın olduğu gözlemlenmektedir.
Ancak, aşırı sıcaklık oyun oynama isteğini azaltabilir. 
Nem de benzer bir etkiye sahiptir, yüksek nem oyun oynama isteğini azaltabilir.

Hava durumu da oyun oynama davranışını etkileyebilir.
Örneğin, güneşli günlerde insanlar daha fazla dışarı çıkmak isteyebilir ve 
bu da oyun oynama olasılığını artırabilirken, yağışlı günlerde dışarı çıkmak 
istemeyebilirler ve bu da oyun oynama olasılığını azaltabilir.

Sonuç olarak, bu verilerden çıkarılabilecek bilimsel bir çıkarım, hava durumu,
sıcaklık ve nem gibi faktörlerin, insanların oyun oynama davranışını etkilediğidir."""
